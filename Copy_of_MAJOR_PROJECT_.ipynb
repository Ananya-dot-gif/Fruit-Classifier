# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya-dot-gif/Fruit-Classifier/blob/main/Copy_of_MAJOR_PROJECT_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_table("/content/drive/MyDrive/Adverk AI 2023/Ananya S Bharadwaj/Datasets/fruit_data_with_colors.txt")
df
#converting  dataset to dataframe
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %% [markdown]
# # New Section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['fruit_label'].value_counts()
#Fruits with label 1 are 19,with label 2 are 5,with label 3 are 19 and with label 4 are 16
# Out:
# fruit_label
# 1    19
# 3    19
# 4    16
# 2     5
# Name: count, dtype: int64

# %%
df['fruit_label'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(x=df['fruit_label'],y=df['fruit_name'])
plt.xticks(rotation=0)
plt.show()
#Different fruit names with different fruit labels are plotted.
#fruit with 4 label is lemon and appke is with 1 fruit label

# %%
df.sample()
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 50            4      lemon       unknown   130    6.0     8.2         0.71

# %%
df['fruit_subtype'].value_counts()
# Out:
# fruit_subtype
# turkey_navel        10
# unknown             10
# cripps_pink          6
# selected_seconds     6
# spanish_belsan       6
# mandarin             5
# braeburn             5
# golden_delicious     5
# granny_smith         3
# spanish_jumbo        3
# Name: count, dtype: int64

# %%
df['fruit_subtype'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 36            3     orange  turkey_navel   160    7.1     7.6         0.76

# %%
df['mass'].value_counts()
# Out:
# mass
# 116    4
# 154    4
# 160    3
# 156    3
# 140    2
# 162    2
# 164    2
# 180    2
# 152    2
# 80     2
# 158    2
# 118    2
# 172    2
# 194    1
# 144    1
# 200    1
# 186    1
# 192    1
# 216    1
# 142    1
# 196    1
# 174    1
# 132    1
# 130    1
# 150    1
# 356    1
# 190    1
# 210    1
# 204    1
# 362    1
# 342    1
# 170    1
# 168    1
# 166    1
# 178    1
# 76     1
# 84     1
# 86     1
# 176    1
# 120    1
# Name: count, dtype: int64

# %%
sns.displot(df['mass'],kde=True)

# %%
sns.barplot(x=df['mass'],y=df['fruit_name'])
plt.xticks(rotation=0)
plt.show()
#mass of orange is highest and mandarin is low according to data

# %%
df['width'].value_counts()
# Out:
# width
# 7.3    7
# 7.1    6
# 7.6    5
# 7.5    5
# 7.2    5
# 7.4    4
# 6.0    4
# 5.8    3
# 5.9    3
# 6.1    2
# 7.0    2
# 8.4    1
# 6.7    1
# 6.3    1
# 6.8    1
# 7.8    1
# 7.7    1
# 9.6    1
# 9.2    1
# 9.0    1
# 8.0    1
# 6.9    1
# 6.2    1
# 6.5    1
# Name: count, dtype: int64

# %%
sns.displot(df['width'],kde=True)

# %%
sns.barplot(x=df['width'],y=df['fruit_name'])
plt.xticks(rotation=0)
plt.show()
#width of apple and orange are almost equivalent,mandarin is smaller according to data

# %%
df['height'].value_counts()
# Out:
# height
# 7.5     5
# 7.1     5
# 7.3     4
# 9.2     4
# 7.2     3
# 8.1     3
# 7.8     3
# 7.4     3
# 7.6     3
# 8.2     2
# 8.0     2
# 7.9     2
# 7.7     2
# 7.0     2
# 4.3     2
# 8.5     2
# 6.8     1
# 9.4     1
# 4.0     1
# 4.6     1
# 4.7     1
# 10.3    1
# 10.5    1
# 10.2    1
# 9.7     1
# 10.1    1
# 8.7     1
# 8.4     1
# Name: count, dtype: int64

# %%
sns.displot(df['height'],kde=True)

# %%
sns.barplot(x=df['height'],y=df['fruit_name'])
plt.xticks(rotation=0)
plt.show()
#height of lemon is more and that of mandarin is less according to data

# %%
sns.displot(df['color_score'],kde=True)

# %%
sns.barplot(x=df['color_score'],y=df['fruit_name'])
plt.xticks(rotation=0)
plt.show()
#the colour score or the shade of Mandarin is more,that of apple and orange are almost same and lemonn is less according to data

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.drop(columns=['fruit_subtype'],inplace=True)

# %%
df.sample()
# Out:
#     fruit_label fruit_name  mass  width  height  color_score
# 27            3     orange   204    7.5     9.2         0.77

# %%
x=df.iloc[:,[0,2,3,4,5]].values  #inputs
x
#The given data is separated to inputs and outputs and they are given out as array
# Out:
# array([[  1.  , 192.  ,   8.4 ,   7.3 ,   0.55],
#        [  1.  , 180.  ,   8.  ,   6.8 ,   0.59],
#        [  1.  , 176.  ,   7.4 ,   7.2 ,   0.6 ],
#        [  2.  ,  86.  ,   6.2 ,   4.7 ,   0.8 ],
#        [  2.  ,  84.  ,   6.  ,   4.6 ,   0.79],
#        [  2.  ,  80.  ,   5.8 ,   4.3 ,   0.77],
#        [  2.  ,  80.  ,   5.9 ,   4.3 ,   0.81],
#        [  2.  ,  76.  ,   5.8 ,   4.  ,   0.81],
#        [  1.  , 178.  ,   7.1 ,   7.8 ,   0.92],
#        [  1.  , 172.  ,   7.4 ,   7.  ,   0.89],
#        [  1.  , 166.  ,   6.9 ,   7.3 ,   0.93],
#        [  1.  , 172.  ,   7.1 ,   7.6 ,   0.92],
#        [  1.  , 154.  ,   7.  ,   7.1 ,   0.88],
#        [  1.  , 164.  ,   7.3 ,   7.7 ,   0.7 ],
#        [  1.  , 152.  ,   7.6 ,   7.3 ,   0.69],
#        [  1.  , 156.  ,   7.7 ,   7.1 ,   0.69],
#        [  1.  , 156.  ,   7.6 ,   7.5 ,   0.67],
#        [  1.  , 168.  ,   7.5 ,   7.6 ,   0.73],
#        [  1.  , 162.  ,   7.5 ,   7.1 ,   0.83],
# ...

# %%
y=df.iloc[:,1].values  #outputs
y
#Output column is Fruit name.
# Out:
# array(['apple', 'apple', 'apple', 'mandarin', 'mandarin', 'mandarin',
#        'mandarin', 'mandarin', 'apple', 'apple', 'apple', 'apple',
#        'apple', 'apple', 'apple', 'apple', 'apple', 'apple', 'apple',
#        'apple', 'apple', 'apple', 'apple', 'apple', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lemon', 'lemon',
#        'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon',
#        'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
#The given Data is split into train and test for easy evaluation of the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.14,random_state=13)

# %%
x_train
# Out:
# array([[  2.  ,  80.  ,   5.9 ,   4.3 ,   0.81],
#        [  4.  , 152.  ,   6.5 ,   8.5 ,   0.72],
#        [  3.  , 160.  ,   7.  ,   7.4 ,   0.81],
#        [  4.  , 194.  ,   7.2 ,  10.3 ,   0.7 ],
#        [  3.  , 160.  ,   7.1 ,   7.6 ,   0.76],
#        [  1.  , 156.  ,   7.7 ,   7.1 ,   0.69],
#        [  4.  , 116.  ,   6.  ,   7.5 ,   0.72],
#        [  4.  , 130.  ,   6.  ,   8.2 ,   0.71],
#        [  3.  , 210.  ,   7.8 ,   8.  ,   0.82],
#        [  1.  , 168.  ,   7.5 ,   7.6 ,   0.73],
#        [  2.  ,  80.  ,   5.8 ,   4.3 ,   0.77],
#        [  2.  ,  86.  ,   6.2 ,   4.7 ,   0.8 ],
#        [  2.  ,  76.  ,   5.8 ,   4.  ,   0.81],
#        [  4.  , 186.  ,   7.2 ,   9.2 ,   0.72],
#        [  1.  , 160.  ,   7.5 ,   7.5 ,   0.86],
#        [  3.  , 154.  ,   7.1 ,   7.5 ,   0.78],
#        [  4.  , 120.  ,   6.  ,   8.4 ,   0.74],
#        [  1.  , 154.  ,   7.  ,   7.1 ,   0.88],
#        [  1.  , 178.  ,   7.1 ,   7.8 ,   0.92],
# ...

# %%
x_test
# Out:
# array([[  3.  , 144.  ,   6.8 ,   7.4 ,   0.75],
#        [  2.  ,  84.  ,   6.  ,   4.6 ,   0.79],
#        [  3.  , 158.  ,   7.1 ,   7.5 ,   0.79],
#        [  4.  , 116.  ,   6.3 ,   7.7 ,   0.72],
#        [  1.  , 192.  ,   8.4 ,   7.3 ,   0.55],
#        [  1.  , 152.  ,   7.6 ,   7.3 ,   0.69],
#        [  3.  , 154.  ,   7.2 ,   7.2 ,   0.82],
#        [  3.  , 204.  ,   7.5 ,   9.2 ,   0.77],
#        [  1.  , 170.  ,   7.6 ,   7.9 ,   0.88]])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=7,metric='euclidean')
#k>1
#k!=even
#k=sqrt(49)=7
#Hence , will decide on 7 nearest neighbors

# %%
#Different classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
#KNeighborsClassifie
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=KNeighborsClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       0.75      0.79      0.77        19
#        lemon       0.76      0.81      0.79        16
#     mandarin       1.00      1.00      1.00         5
#       orange       0.82      0.74      0.78        19
#
#     accuracy                           0.80        59
#    macro avg       0.83      0.83      0.83        59
# weighted avg       0.80      0.80      0.80        59
#
# accuracy score 0.7966101694915254
#
# Confusion matrix [[15  1  0  3]
#  [ 3 13  0  0]
#  [ 0  0  5  0]
#  [ 2  3  0 14]]

# %%
#ExtraTreesClassifier
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=ExtraTreesClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        19
#        lemon       1.00      1.00      1.00        16
#     mandarin       1.00      1.00      1.00         5
#       orange       1.00      1.00      1.00        19
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
#
# accuracy score 1.0
#
# Confusion matrix [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0  5  0]
#  [ 0  0  0 19]]

# %%
#RandomForestClassifier
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=RandomForestClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        19
#        lemon       1.00      1.00      1.00        16
#     mandarin       1.00      1.00      1.00         5
#       orange       1.00      1.00      1.00        19
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
#
# accuracy score 1.0
#
# Confusion matrix [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0  5  0]
#  [ 0  0  0 19]]

# %%
#DecisionTreeClassifier
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=DecisionTreeClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        19
#        lemon       1.00      1.00      1.00        16
#     mandarin       1.00      1.00      1.00         5
#       orange       1.00      1.00      1.00        19
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
#
# accuracy score 1.0
#
# Confusion matrix [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0  5  0]
#  [ 0  0  0 19]]

# %%
#AdaBoostClassifier
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=AdaBoostClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       0.00      0.00      0.00        19
#        lemon       1.00      1.00      1.00        16
#     mandarin       0.12      1.00      0.21         5
#       orange       0.00      0.00      0.00        19
#
#     accuracy                           0.36        59
#    macro avg       0.28      0.50      0.30        59
# weighted avg       0.28      0.36      0.29        59
#
# accuracy score 0.3559322033898305
#
# Confusion matrix [[ 0  0 19  0]
#  [ 0 16  0  0]
#  [ 0  0  5  0]
#  [ 0  0 19  0]]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#GradientBoostingClassifier
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,3,4])
    ],remainder='passthrough')
step2=GradientBoostingClassifier()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x,y)
y_pred=pipe.predict(x)
y_pred
print("classification report",classification_report(y,y_pred))
print("accuracy score",accuracy_score(y,y_pred))
print("\nConfusion matrix",confusion_matrix(y,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        19
#        lemon       1.00      1.00      1.00        16
#     mandarin       1.00      1.00      1.00         5
#       orange       1.00      1.00      1.00        19
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59
#
# accuracy score 1.0
#
# Confusion matrix [[19  0  0  0]
#  [ 0 16  0  0]
#  [ 0  0  5  0]
#  [ 0  0  0 19]]

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 65.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.3 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))
st.title("Fruit Classifier")
fruit_label=st.selectbox("The fruit label",df['fruit_label'].unique(),index=0)
mass=st.selectbox("The fruit weighs",df['mass'].unique(),index=0)
width=st.slider("Width of the fruit",min_value=4.5,max_value=10.0,value=5.0,step=0.01)
height=st.selectbox("Height of the fruit",df['height'].unique(),index=4)
color_score=st.selectbox("Color score of the fruit",df['color_score'].unique(),index=0)
if st.button("PREDICT FRUIT"):
    query=np.array([[fruit_label,mass,width,height,color_score]])
    op=pipe.predict(query)
    st.subheader("This fruit is " + str(op[0]))
# Out:
# Writing app.py

# %%
#streamlit app to predict the fruit name when width,mass,height and color score of the fruit is known
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹
# ...
#
# ⠸⠼⠴⠦⠧⠇Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.139.86.150:8501
